# %%
import pandas as pd

# %% [markdown]
# # Dataset 1 - Car Pricing
#
# Modelo de regresion:
#
# Que relacion hay entre:
#
# El Precio y
#
# - Año
# - Caja de velocidades ( manual o automatico)
# - Potencia
# - Kilometros
#
# Modelo de clasificacion:
#
# - Tipo de vehiculos
# - Año
# - Manual o automatico
# - Potencia
# - Kilometros
# - Combustible
# - Marca

# %%
url1 = 'https://raw.githubusercontent.com/SebastianFurquet/Datasets-Furquet---Seleccionados/main/1_car_pricing.csv'
df1 = pd.read_csv(url1, sep=',')
df1.head()
# Out:
#    index          dateCrawled                            name  seller  \
# 0      0  2016-03-24 11:52:17                      Golf_3_1.6  privat
# 1      1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat
# 2      2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat
# 3      3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat
# 4      4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat
#
#   offerType  price abtest vehicleType  yearOfRegistration    gearbox  ...  \
# 0   Angebot    480   test         NaN                1993    manuell  ...
# 1   Angebot  18300   test       coupe                2011    manuell  ...
# 2   Angebot   9800   test         suv                2004  automatik  ...
# 3   Angebot   1500   test  kleinwagen                2001    manuell  ...
# 4   Angebot   3600   test  kleinwagen                2008    manuell  ...
#
#    model kilometer  monthOfRegistration  fuelType       brand  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   index                371528 non-null  int64
#  1   dateCrawled          371528 non-null  object
#  2   name                 371528 non-null  object
#  3   seller               371528 non-null  object
#  4   offerType            371528 non-null  object
#  5   price                371528 non-null  int64
#  6   abtest               371528 non-null  object
#  7   vehicleType          333659 non-null  object
#  8   yearOfRegistration   371528 non-null  int64
#  9   gearbox              351319 non-null  object
#  10  powerPS              371528 non-null  int64
#  11  model                351044 non-null  object
#  12  kilometer            371528 non-null  int64
#  13  monthOfRegistration  371528 non-null  int64
#  14  fuelType             338142 non-null  object
# ...

# %% [markdown]
# # Dataset 2 - Prioridad Accidentes
#
# Preguntas:
# ¿En que me baso para darle prioridad a un accidente? ¿Como los puedo clasificar?
#
# - Tipo de evento
# - Relacion entre los vehiculos ( tipo de vehiculos )
# - ¿Hubo muertos? (Total Occisos) - Segmentacion: cuantos son Hombres, mujeres, se desconoce.
# - ¿Hubo lesionados? (Total Lesionados ) - Segmentacion: cuantos son Hombres, mujeres, se desconoce.
# - Fallecidos / Lesionados ( Rangos de edades )
# - Fallecidos / Lesionados ( Peatones / Ciclistas / Pasajeros / Motociclista / Conductor )
# - Fallecidos / Lesionados ( Diagnostico )
#
# Este Dataset me parece que tiene algunos datos inconsistentes

# %%
url2 = 'https://raw.githubusercontent.com/SebastianFurquet/Datasets-Furquet---Seleccionados/main/3_prioridad_accidentes.csv'
df2 = pd.read_csv(url2, sep=',')
df2.head()
# Out:
# C:\Users\sebas\AppData\Local\Temp\ipykernel_11072\893893144.py:2: DtypeWarning: Columns (4,17,18,19,20,21,22,24,25,26,49,53,58,59,60,61,62,63,64,66,67,68,69,70,71,74,75,76,77,78,79,80,83,84,85,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv(url2, sep=',')
#           no_folio fecha_evento    mes      hora condicion tipo_de_evento  \
# 0  BJ/200406/03499   2020-04-06  abril  12:50:00       NaN         CHOQUE
# 1  C5/200406/05748   2020-04-06  abril  18:31:00       NaN         CHOQUE
# 2  C5/200406/05802   2020-04-06  abril  18:39:00       NaN         CHOQUE
# 3  IZ/200406/03058   2020-04-06  abril  11:38:00       NaN      DERRAPADO
# 4  C5/200406/03762   2020-04-06  abril  13:31:00       NaN      DERRAPADO
#
#    coordenada_x  coordenada_y         punto_1                    punto_2  ...  \
# 0     19.368116    -99.142903       EJE 7 SUR                   ANTILLAS  ...
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109691 entries, 0 to 109690
# Data columns (total 88 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   no_folio                                    109690 non-null  object
#  1   fecha_evento                                109691 non-null  object
#  2   mes                                         109691 non-null  object
#  3   hora                                        109661 non-null  object
#  4   condicion                                   37307 non-null   object
#  5   tipo_de_evento                              109691 non-null  object
#  6   coordenada_x                                109684 non-null  float64
#  7   coordenada_y                                109687 non-null  float64
#  8   punto_1                                     109691 non-null  object
# ...

# %% [markdown]
# # Dataset 3 - Reservas Hoteles
#
#
# Ponosticar la probabilidad de cancelaciones de reservas de hotel.

# %%
url3= 'https://raw.githubusercontent.com/SebastianFurquet/Datasets-Furquet---Seleccionados/main/6_reservas_hoteles.csv'
df3 = pd.read_csv(url3, sep=',')
df3.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
# ...
